# %% [markdown]
# # Rifqi Akbar Mubarak
# # PYTN-KS19-017
# # Kelompok 1
# # Python for Data Science by Hacktiv8
# # **Final Projects 4**

# %% [markdown]
# ## About Dataset
# The sample Dataset summarizes the usage behavior of about 9000 active credit card holders during the last 6 months. The file is at a customer level with 18 behavioral variables.

# %% [markdown]
# 1. CUST_ID, Identifikasi Pemegang Kartu Kredit (categorical)
# 2. BALANCE, Jumlah saldo yang tersisa di akun mereka untuk melakukan pembelian
# 3. BALANCE_FREQUENCY, Seberapa sering Saldo diperbarui, skor antara 0 dan 1 (1 = sering diperbarui, 0 = tidak sering diperbarui)
# 4. PURCHASES, Jumlah pembelian yang dilakukan dari akun
# 5. ONEOFF_PURCHASES, Jumlah pembelian maksimum dilakukan dalam sekali jalan
# 6. INSTALLMENTS_PURCHASES, Jumlah pembelian dilakukan secara angsuran
# 7. CASH_ADVANCE, Uang tunai di muka yang diberikan oleh pengguna
# 8. PURCHASES_FREQUENCY, Seberapa sering Pembelian dilakukan, skor antara 0 dan 1 (1 = sering dibeli, 0 = tidak sering dibeli)
# 9. ONEOFF_PURCHASES_FREQUENCY, How sering Pembelian terjadi dalam sekali jalan (1 = sering dibeli, 0 = tidak sering dibeli)
# 10. PURCHASES_INSTALLMENTS_FREQUENCY, Seberapa sering pembelian secara mencicil dilakukan (1 = sering dilakukan, 0 = tidak sering dilakukan)
# 11. CASH_ADVANCE_FREQUENCY, Seberapa sering uang tunai di muka dibayarkan
# 12. CASH_ADVANCE_TRX, Jumlah Transaksi yang dilakukan dengan "Cash in Advance\
# 13. PURCHASES_TRX, Jumlah transaksi pembelian yang dilakukan
# 14. CREDIT_LIMIT, Batas Kartu Kredit untuk pengguna
# 15. PAYMENTS, Jumlah Pembayaran yang dilakukan oleh pengguna
# 16. MINIMUM_PAYMENTS, Jumlah minimum pembayaran yang dilakukan oleh pengguna
# 17. PRC_FULL_PAYMENT, Persentase pembayaran penuh yang dibayarkan oleh pengguna
# 18. TENURE, Jangka waktu layanan kartu kredit untuk pengguna

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style('whitegrid')
plt.style.use('fivethirtyeight')

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import davies_bouldin_score

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Loading

# %%
dataset = pd.read_csv("CC GENERAL.csv", delimiter=',', encoding = "utf-8")
dataset.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
dataset.columns = dataset.columns.str.lower()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   cust_id                           8950 non-null   object
#  1   balance                           8950 non-null   float64
#  2   balance_frequency                 8950 non-null   float64
#  3   purchases                         8950 non-null   float64
#  4   oneoff_purchases                  8950 non-null   float64
#  5   installments_purchases            8950 non-null   float64
#  6   cash_advance                      8950 non-null   float64
#  7   purchases_frequency               8950 non-null   float64
#  8   oneoff_purchases_frequency        8950 non-null   float64
#  9   purchases_installments_frequency  8950 non-null   float64
#  10  cash_advance_frequency            8950 non-null   float64
#  11  cash_advance_trx                  8950 non-null   int64
#  12  purchases_trx                     8950 non-null   int64
#  13  credit_limit                      8949 non-null   float64
#  14  payments                          8950 non-null   float64
#  15  minimum_payments                  8637 non-null   float64
#  16  prc_full_payment                  8950 non-null   float64
#  17  tenure                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
dataset.shape
# Out:
# (8950, 18)

# %% [markdown]
# Dataset ini memiliki jumlah data sebanyak 8636 dengan total 18 kolom.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Pembersihan data adalah tahap yang sangat penting sebelum pengolahan data untuk analisis maupun modeling dilakukan. Pastikan data yang kita miliki sudah tidak mengandung missing values/invalid values, maupun data duplikat agar tidak terjadi bias pada analisis atau modeling yang dilakukan.

# %% [markdown]
# ### Identify Missing Values

# %%
def check_missing_value(data):
    total = data.isnull().sum().sort_values(ascending = False)
    percentage = (data.isnull().sum() / data.isnull().count()*100).sort_values(ascending = True)
    return pd.concat([total, percentage], axis=1, keys = ['total', 'percentage'])

# %%
check_missing_value(dataset).style.background_gradient(cmap = 'Spectral')
# Out:
# <style type="text/css">
# #T_c34a9_row0_col0, #T_c34a9_row0_col1 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_c34a9_row1_col0, #T_c34a9_row1_col1, #T_c34a9_row2_col0, #T_c34a9_row2_col1, #T_c34a9_row3_col0, #T_c34a9_row3_col1, #T_c34a9_row4_col0, #T_c34a9_row4_col1, #T_c34a9_row5_col0, #T_c34a9_row5_col1, #T_c34a9_row6_col0, #T_c34a9_row6_col1, #T_c34a9_row7_col0, #T_c34a9_row7_col1, #T_c34a9_row8_col0, #T_c34a9_row8_col1, #T_c34a9_row9_col0, #T_c34a9_row9_col1, #T_c34a9_row10_col0, #T_c34a9_row10_col1, #T_c34a9_row11_col0, #T_c34a9_row11_col1, #T_c34a9_row12_col0, #T_c34a9_row12_col1, #T_c34a9_row13_col0, #T_c34a9_row13_col1, #T_c34a9_row14_col0, #T_c34a9_row14_col1, #T_c34a9_row15_col0, #T_c34a9_row15_col1, #T_c34a9_row16_col0, #T_c34a9_row16_col1, #T_c34a9_row17_col0, #T_c34a9_row17_col1 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c34a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c34a9_level0_col0" class="col_heading level0 col0" >total</th>
#       <th id="T_c34a9_level0_col1" class="col_heading level0 col1" >percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c34a9_level0_row0" class="row_heading level0 row0" >minimum_payments</th>
#       <td id="T_c34a9_row0_col0" class="data row0 col0" >313</td>
#       <td id="T_c34a9_row0_col1" class="data row0 col1" >3.497207</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row1" class="row_heading level0 row1" >credit_limit</th>
#       <td id="T_c34a9_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_c34a9_row1_col1" class="data row1 col1" >0.011173</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row2" class="row_heading level0 row2" >cust_id</th>
#       <td id="T_c34a9_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_c34a9_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row3" class="row_heading level0 row3" >balance</th>
#       <td id="T_c34a9_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_c34a9_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row4" class="row_heading level0 row4" >prc_full_payment</th>
#       <td id="T_c34a9_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_c34a9_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row5" class="row_heading level0 row5" >payments</th>
#       <td id="T_c34a9_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_c34a9_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row6" class="row_heading level0 row6" >purchases_trx</th>
#       <td id="T_c34a9_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_c34a9_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row7" class="row_heading level0 row7" >cash_advance_trx</th>
#       <td id="T_c34a9_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_c34a9_row7_col1" class="data row7 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row8" class="row_heading level0 row8" >cash_advance_frequency</th>
#       <td id="T_c34a9_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_c34a9_row8_col1" class="data row8 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row9" class="row_heading level0 row9" >purchases_installments_frequency</th>
#       <td id="T_c34a9_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_c34a9_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row10" class="row_heading level0 row10" >oneoff_purchases_frequency</th>
#       <td id="T_c34a9_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_c34a9_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row11" class="row_heading level0 row11" >purchases_frequency</th>
#       <td id="T_c34a9_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_c34a9_row11_col1" class="data row11 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row12" class="row_heading level0 row12" >cash_advance</th>
#       <td id="T_c34a9_row12_col0" class="data row12 col0" >0</td>
#       <td id="T_c34a9_row12_col1" class="data row12 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row13" class="row_heading level0 row13" >installments_purchases</th>
#       <td id="T_c34a9_row13_col0" class="data row13 col0" >0</td>
#       <td id="T_c34a9_row13_col1" class="data row13 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row14" class="row_heading level0 row14" >oneoff_purchases</th>
#       <td id="T_c34a9_row14_col0" class="data row14 col0" >0</td>
#       <td id="T_c34a9_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row15" class="row_heading level0 row15" >purchases</th>
#       <td id="T_c34a9_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_c34a9_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row16" class="row_heading level0 row16" >balance_frequency</th>
#       <td id="T_c34a9_row16_col0" class="data row16 col0" >0</td>
#       <td id="T_c34a9_row16_col1" class="data row16 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c34a9_level0_row17" class="row_heading level0 row17" >tenure</th>
#       <td id="T_c34a9_row17_col0" class="data row17 col0" >0</td>
#       <td id="T_c34a9_row17_col1" class="data row17 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
#      cust_id      balance  balance_frequency  purchases  oneoff_purchases  \
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 45    C10047  2242.311686           1.000000     437.00             97.00
# 47    C10049  3910.111237           1.000000       0.00              0.00
# 54    C10056     6.660517           0.636364     310.00              0.00
# 55    C10057  1311.995984           1.000000    1283.90           1283.90
# ...      ...          ...                ...        ...               ...
# 8919  C19160    14.524779           0.333333     152.00            152.00
# 8929  C19170   371.527312           0.333333       0.00              0.00
# 8935  C19176   183.817004           1.000000     465.90              0.00
# 8944  C19185   193.571722           0.833333    1012.73           1012.73
# 8946  C19187    19.183215           1.000000     300.00              0.00
#
#       installments_purchases  cash_advance  purchases_frequency  \
# 3                        0.0    205.788017             0.083333
# 45                     340.0    184.648692             0.333333
# 47                       0.0   1980.873201             0.000000
# 54                     310.0      0.000000             0.666667
# 55                       0.0      0.000000             0.250000
# ...                      ...           ...                  ...
# 8919                     0.0      0.000000             0.333333
# 8929                     0.0   1465.407927             0.000000
# 8935                   465.9      0.000000             1.000000
# 8944                     0.0      0.000000             0.333333
# 8946                   300.0      0.000000             1.000000
#
#       oneoff_purchases_frequency  purchases_installments_frequency  \
# 3                       0.083333                          0.000000
# 45                      0.083333                          0.333333
# 47                      0.000000                          0.000000
# 54                      0.000000                          0.666667
# 55                      0.250000                          0.000000
# ...                          ...                               ...
# 8919                    0.333333                          0.000000
# 8929                    0.000000                          0.000000
# 8935                    0.000000                          0.833333
# 8944                    0.333333                          0.000000
# 8946                    0.000000                          0.833333
#
#       cash_advance_frequency  cash_advance_trx  purchases_trx  credit_limit  \
# 3                   0.083333                 1              1        7500.0
# 45                  0.166667                 2              5        2400.0
# 47                  0.500000                 7              0        4200.0
# 54                  0.000000                 0              8        1000.0
# 55                  0.000000                 0              6        6000.0
# ...                      ...               ...            ...           ...
# 8919                0.000000                 0              2        1500.0
# 8929                0.166667                 5              0        1500.0
# 8935                0.000000                 0              6        1500.0
# 8944                0.000000                 0              2        4000.0
# 8946                0.000000                 0              6        1000.0
#
#         payments  minimum_payments  prc_full_payment  tenure
# 3       0.000000               NaN               0.0      12
# 45      0.000000               NaN               0.0      12
# 47      0.000000               NaN               0.0      12
# 54    417.016763               NaN               0.0      12
# 55      0.000000               NaN               0.0      12
# ...          ...               ...               ...     ...
# 8919    0.000000               NaN               0.0       6
# 8929    0.000000               NaN               0.0       6
# 8935    0.000000               NaN               0.0       6
# 8944    0.000000               NaN               0.0       6
# 8946  275.861322               NaN               0.0       6
#
# [314 rows x 18 columns]

# %% [markdown]
# Data diatas merupakan list data yang memiliki Null Values pada kolom <b>"minimum_payments"</b> atau <b>"credit_limit"</b> dengan total 314 baris data. Data yang kosong ini dapat diimpute dengan berbagai metode, salah satunya adalah impute dengan median atau mean. Dataset ini pada kolom <b>"minimum_payments"</b> yang memiliki 313 data kosong akan diimpute dengan median, dan <b>"credit_limit"</b> dengan 1 missing value akan diisi dengan mean.

# %%
dataset['minimum_payments'].fillna(dataset['minimum_payments'].median(), inplace=True)
dataset['credit_limit'].fillna(dataset['credit_limit'].mean(), inplace=True)

# %%
dataset.isnull().sum().sum()
# Out:
# 0

# %%
dataset.shape
# Out:
# (8950, 18)

# %% [markdown]
# ### Identify Duplicate Data

# %%
dataset.duplicated().values.any()
# Out:
# False

# %% [markdown]
# Tidak ada data yang duplikasi pada dataset ini.

# %%
dataset.tail()
# Out:
#      cust_id     balance  balance_frequency  purchases  oneoff_purchases  \
# 8945  C19186   28.493517           1.000000     291.12              0.00
# 8946  C19187   19.183215           1.000000     300.00              0.00
# 8947  C19188   23.398673           0.833333     144.40              0.00
# 8948  C19189   13.457564           0.833333       0.00              0.00
# 8949  C19190  372.708075           0.666667    1093.25           1093.25
#
#       installments_purchases  cash_advance  purchases_frequency  \
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       oneoff_purchases_frequency  purchases_installments_frequency  \
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       cash_advance_frequency  cash_advance_trx  purchases_trx  credit_limit  \
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#         payments  minimum_payments  prc_full_payment  tenure
# 8945  325.594462         48.886365              0.50       6
# 8946  275.861322        312.343947              0.00       6
# 8947   81.270775         82.418369              0.25       6
# 8948   52.549959         55.755628              0.25       6
# 8949   63.165404         88.288956              0.00       6

# %% [markdown]
# ### Drop Unused Columns

# %% [markdown]
# Drop kolom pada dataset yang tidak dibutuhkan. Pada kasus ini, kolom <b>"cust_id"</b> tidak dibutuhkan untuk analisis maupun modeling.

# %%
dataset.drop(columns='cust_id', inplace=True)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
dataset.describe()
# Out:
#             balance  balance_frequency     purchases  oneoff_purchases  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        installments_purchases  cash_advance  purchases_frequency  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        oneoff_purchases_frequency  purchases_installments_frequency  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        cash_advance_frequency  cash_advance_trx  purchases_trx  credit_limit  \
# count             8950.000000       8950.000000    8950.000000   8950.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.612411
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            payments  minimum_payments  prc_full_payment       tenure
# count   8950.000000       8950.000000       8950.000000  8950.000000
# mean    1733.143852        844.906767          0.153715    11.517318
# std     2895.063757       2332.792322          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        170.857654          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        788.713501          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %%
plt.rcParams['figure.figsize'] = (12,8)
sns.heatmap(dataset.corr(), cmap='viridis', annot=True)
plt.title('Heat Map', fontsize =20)
# Out:
# Text(0.5, 1.0, 'Heat Map')

# %% [markdown]
# Di sini kita bisa melihat korelasi dataset. <b>purchases</b> dan <b>oneoff_purchases</b> memiliki korelasi yang sangat tinggi seperti yang kita perkirakan pada 0,92. Ini sama untuk variabel dan bagian penghitung skor frekuensinya seperti  <b>cash advance trx</b> dan <b>cash advance frequency</b> di 0,8. Tidak heran hal seperti keseimbangan dan pembayaran memiliki korelasi yang buruk. Ini memberi tahu bahwa data memang masuk akal.

# %%
plt.rcParams['figure.figsize'] =(20,40)

for num in range(0,17):
    ax = plt.subplot(9,2,num+1)
    col = dataset.columns[num]
    sns.distplot(dataset[col], ax=ax)
    
# plt.savefig('all_dist.png')

# %% [markdown]
# Di atas adalah plot distribusi dari setiap variabel dalam dataset.
# Di sini kita memiliki ikhtisar dari seluruh distribusi kerangka data. Kita dapat langsung melihat bahwa distribusi ini sangat miring ke kiri dan ada banyak nilai nol.

# %%
plt.rcParams['figure.figsize'] = (12,8)

sns.distplot(dataset['balance'],bins=150, color='red')
plt.title('Distribution of Balance', size=20)
plt.xlabel('Balance')
# Out:
# Text(0.5, 0, 'Balance')

# %%
dataset['balance'].value_counts(ascending=False)
# Out:
# balance
# 0.000000       80
# 40.900749       1
# 1213.551338     1
# 1253.188317     1
# 5058.299635     1
#                ..
# 8791.161142     1
# 2320.402196     1
# 7215.745096     1
# 1013.233120     1
# 372.708075      1
# Name: count, Length: 8871, dtype: int64

# %% [markdown]
# Distribusi <b>"balance"</b> (jumlah total uang hutang anda kepada perusahaan kartu kredit) berkisar dari <b>0 dollar</b> hingga <b>20.000 dollar</b>. Disini terlihat sangat jelas ada jumlah kartu kredit yang sangat tinggi dengan saldo <b>0 dollar</b>. Ini bisa jadi karena orang memegang apa yang disebut "zero balance card". Ini artinya menjaga saldo Anda rendah (dalam hal ini 0 dollar) tetapi batas kreditnya tinggi, ini akan meningkatkan rasio pemanfaatan kredit dan meningkatkan skor kredit.

# %%
plt.rcParams['figure.figsize'] = (12,8)

sns.countplot(y=dataset['balance_frequency'],order = dataset['balance_frequency'].value_counts().index)
plt.ylabel('Balance Frequncy Score (0-1)')
plt.title('Counts of Balance Frequency Score', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Counts of Balance Frequency Score')

# %% [markdown]
# Frekuensi saldo adalah skor 0-1, yang diberikan ke akun berdasarkan seberapa sering saldo akun diperbarui. Salah satunya adalah skor tertinggi. Jadi pada dasarnya ini adalah ukuran seberapa sering orang menggunakan kartu kreditnya. Seperti yang dapat lihat di sini sebagian besar akun memiliki skor satu, skor terbaik, artinya kebanyakan orang sering menggunakan kartu kredit dan hanya sejumlah kecil orang yang menjaga kartu mereka relatif tidak aktif.

# %%
plt.rcParams['figure.figsize'] = (12,8)

sns.distplot(dataset['purchases'], color='orange', bins=100)
plt.title('Distribution of Purchases', size=20)
plt.xlabel('Purchases')
# Out:
# Text(0.5, 0, 'Purchases')

# %% [markdown]
# Banyak orang memiliki jumlah pembelian 0. Ini berbanding lurus karena sebelumnya juga dapat dilihat bahwa banyak orang memegang kartu saldo nol.

# %%
plt.subplot(1,2,1)
sns.distplot(dataset['oneoff_purchases'], color='green')
plt.title('Distribution of One Off Purchase', fontsize = 20)
plt.xlabel('Amount')


plt.subplot(1,2,2)
sns.distplot(dataset['installments_purchases'], color='red')
plt.title('Distribution of Installment Purchase', fontsize = 20)
plt.xlabel('Amount')
# Out:
# Text(0.5, 0, 'Amount')

# %% [markdown]
# Plot diatas merupakan perbandingan antara distribusi pembelian satu kali dan pembelian angsuran.
#
# Pembelian satu kali naik hingga lebih dari 40.000 dolar sedangkan pembelian cicilan tertinggi naik menjadi sekitar 25.000 dolar.

# %%
plt.rcParams['figure.figsize'] = (12, 15)

plt.subplot(2, 2, 1)
sns.scatterplot(x='purchases', y='credit_limit', data=dataset)
plt.title('Credit Limit And Purchases', fontsize=15)
plt.xlabel('Purchases')

plt.subplot(2, 2, 2)
sns.scatterplot(x='balance', y='credit_limit', data=dataset)
plt.title('Credit Limit And Balance', fontsize =15)
plt.xlabel('Balance')
plt.ylabel('Credit limit')

plt.subplot(2,2,3)
sns.scatterplot(x='oneoff_purchases' , y='credit_limit', data=dataset)
plt.title('Credit Limit And One Off Purchases', fontsize =15)
plt.xlabel('One off purchases')
plt.ylabel('Credit limit')

plt.subplot(2,2,4)
sns.scatterplot(x='installments_purchases', y='credit_limit', data=dataset)
plt.title('Credit Limit And Installments Purchases', fontsize =15)
plt.xlabel('Installment Purchases')
plt.ylabel('Credit limit')
# Out:
# Text(0, 0.5, 'Credit limit')

# %% [markdown]
# Data di atas adalah scatterplot antara <b>credit_limit</b> dengan <b>saldo dan berbagai jenis pembelian</b>
#
# Tampaknya tidak ada korelasi yang kuat antara <b>credit_limit</b> dan variabel-variabel tersebut. Bahkan, jumlah pembelian cenderung tetap nol sementara batas kredit meningkat. Ini menunjukkan bahwa pengguna kartu kredit benar-benar ingin menjaga saldo mereka tetap rendah untuk memanfaatkan kredit mereka. Ini mungkin menandakan bahwa, kartu kredit adalah alat untuk pemanfaatan kredit daripada alat belanja.
#
# Adapun keseimbangan, tampaknya ada korelasi yang lebih baik bahwa ketika credit_limit naik, balance juga naik tetapi juga jelas untuk melihat bahwa ada juga poin di mana balance tetap nol tetapi credit_limit naik.

# %%
plt.rcParams['figure.figsize'] = (15,8)

plt.subplot(1,2,1)
sns.boxenplot(dataset['purchases_trx'])
plt.title('Total Number of Purcahses')
plt.xlabel('Purchases')

plt.subplot(1,2,2)
sns.boxenplot(dataset['cash_advance_trx'])
plt.title('Total Number of Transaction Made with Cash Advance')
plt.xlabel('Purchases')
# Out:
# Text(0.5, 0, 'Purchases')

# %% [markdown]
# Di atas adalah plot kotak dari jumlah total <b>purchases_trx</b> dan <b>cash_advance_trx</b>.
#
# Seperti yang diharapkan, ada sejumlah besar orang dengan jumlah transaksi yang rendah karena kita berasumsi bahwa orang menggunakan kartu kredit untuk pemanfaatan kredit dan bukan untuk pembelian. Dan hanya ada beberapa orang yang membeli dengan kuantitas tinggi. Beberapa orang purchases lebih dari 300 kali dan lebih sedikit yang melakukan lebih dari 100 kali dengan cash_advance_trx.

# %%
plt.rcParams['figure.figsize'] = (10,6)
sns.countplot(x="tenure", data=dataset, palette="rainbow")
plt.title('Counts of Tenures', fontsize = 20)
plt.xlabel('Months')
# Out:
# Text(0.5, 0, 'Months')

# %% [markdown]
# Tenor adalah jangka waktu pelunasan kartu, berkisar antara 6-12 bulan. Menariknya sebagian besar kartu adalah kartu 12 bulan. Semakin lama masa tenor, semakin banyak tingkat bunga yang dibayarkan.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Scaling Data

# %%
scaler = StandardScaler()

# %%
df_scaler = pd.DataFrame(scaler.fit_transform(dataset), index=dataset.index, columns = dataset.columns)
df_scaler
# Out:
#        balance  balance_frequency  purchases  oneoff_purchases  \
# 0    -0.731989          -0.249434  -0.424900         -0.356934
# 1     0.786961           0.134325  -0.469552         -0.356934
# 2     0.447135           0.518084  -0.107668          0.108889
# 3     0.049099          -1.016953   0.232058          0.546189
# 4    -0.358775           0.518084  -0.462063         -0.347294
# ...        ...                ...        ...               ...
# 8945 -0.737950           0.518084  -0.333293         -0.356934
# 8946 -0.742423           0.518084  -0.329136         -0.356934
# 8947 -0.740398          -0.185477  -0.401965         -0.356934
# 8948 -0.745174          -0.185477  -0.469552         -0.356934
# 8949 -0.572575          -0.889033   0.042146          0.301732
#
#       installments_purchases  cash_advance  purchases_frequency  \
# 0                  -0.349079     -0.466786            -0.806490
# 1                  -0.454576      2.605605            -1.221758
# 2                  -0.454576     -0.466786             1.269843
# 3                  -0.454576     -0.368653            -1.014125
# 4                  -0.454576     -0.466786            -1.014125
# ...                      ...           ...                  ...
# 8945               -0.132643     -0.466786             1.269843
# 8946               -0.122823     -0.466786             1.269843
# 8947               -0.294893     -0.466786             0.854576
# 8948               -0.454576     -0.449352            -1.221758
# 8949               -0.454576     -0.406205             0.439310
#
#       oneoff_purchases_frequency  purchases_installments_frequency  \
# 0                      -0.678661                         -0.707313
# 1                      -0.678661                         -0.916995
# 2                       2.673451                         -0.916995
# 3                      -0.399319                         -0.916995
# 4                      -0.399319                         -0.916995
# ...                          ...                               ...
# 8945                   -0.678661                          1.179833
# 8946                   -0.678661                          1.179833
# 8947                   -0.678661                          0.760469
# 8948                   -0.678661                         -0.916995
# 8949                    1.556082                         -0.916995
#
#       cash_advance_frequency  cash_advance_trx  purchases_trx  credit_limit  \
# 0                  -0.675349         -0.476070      -0.511333     -0.960433
# 1                   0.573963          0.110074      -0.591796      0.688639
# 2                  -0.675349         -0.476070      -0.109020      0.826062
# 3                  -0.258913         -0.329534      -0.551565      0.826062
# 4                  -0.675349         -0.476070      -0.551565     -0.905464
# ...                      ...               ...            ...           ...
# 8945               -0.675349         -0.476070      -0.350408     -0.960433
# 8946               -0.675349         -0.476070      -0.350408     -0.960433
# 8947               -0.675349         -0.476070      -0.390639     -0.960433
# 8948                0.157527         -0.182998      -0.591796     -1.097856
# 8949                0.990398         -0.182998       0.333524     -0.905464
#
#       payments  minimum_payments  prc_full_payment    tenure
# 0    -0.528979         -0.302400         -0.525551  0.360680
# 1     0.818642          0.097500          0.234227  0.360680
# 2    -0.383805         -0.093293         -0.525551  0.360680
# 3    -0.598688         -0.228307         -0.525551  0.360680
# 4    -0.364368         -0.257266         -0.525551  0.360680
# ...        ...               ...               ...       ...
# 8945 -0.486217         -0.341250          1.183951 -4.122768
# 8946 -0.503396         -0.228307         -0.525551 -4.122768
# 8947 -0.570615         -0.326875          0.329200 -4.122768
# 8948 -0.580536         -0.338305          0.329200 -4.122768
# 8949 -0.576869         -0.324358         -0.525551 -4.122768
#
# [8950 rows x 17 columns]

# %% [markdown]
# ## Clustering

# %%
data = dataset.copy()

# %% [markdown]
# ### K-Means

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters= i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(df_scaler)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11), wcss, marker='o')
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('wcss')
plt.show()

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state=0)
kmeans.fit(df_scaler)
pred = kmeans.predict(df_scaler)

# %%
# Building the model at 4 clusters, add the label to the dataframe
data['Cluster KMeans'] = pred
data['Cluster KMeans'].value_counts()
# Out:
# Cluster KMeans
# 3    3977
# 0    3367
# 1    1197
# 2     409
# Name: count, dtype: int64

# %% [markdown]
# Klaster 0 = Pembelanja tertinggi<br>
# kluster 1 = Pembelanja sedang<br>
# kluster 2 = Pembelanja rendah<br>
# kluster 3 = Saldo nol & pembelanja rendah

# %%
data.head()
# Out:
#        balance  balance_frequency  purchases  oneoff_purchases  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    installments_purchases  cash_advance  purchases_frequency  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    oneoff_purchases_frequency  purchases_installments_frequency  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    cash_advance_frequency  cash_advance_trx  purchases_trx  credit_limit  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       payments  minimum_payments  prc_full_payment  tenure  Cluster KMeans
# 0   201.802084        139.509787          0.000000      12               3
# 1  4103.032597       1072.340217          0.222222      12               1
# 2   622.066742        627.284787          0.000000      12               0
# 3     0.000000        312.343947          0.000000      12               3
# 4   678.334763        244.791237          0.000000      12               3

# %%
data_transf_kmeans = data.groupby('Cluster KMeans').mean()
data_transf_kmeans
# Out:
#                     balance  balance_frequency    purchases  oneoff_purchases  \
# Cluster KMeans
# 0                894.907458           0.934734  1236.178934        593.974874
# 1               4602.449658           0.968389   501.862982        320.188797
# 2               3551.153761           0.986879  7681.620098       5095.878826
# 3               1012.658327           0.789924   270.041785        209.937299
#
#                 installments_purchases  cash_advance  purchases_frequency  \
# Cluster KMeans
# 0                           642.478274    210.570626             0.885165
# 1                           181.759123   4521.509581             0.287832
# 2                          2587.208264    653.638891             0.946418
# 3                            60.371441    596.509903             0.170145
#
#                 oneoff_purchases_frequency  purchases_installments_frequency  \
# Cluster KMeans
# 0                                 0.297070                          0.711842
# 1                                 0.138911                          0.185671
# 2                                 0.739031                          0.788060
# 3                                 0.086301                          0.080558
#
#                 cash_advance_frequency  cash_advance_trx  purchases_trx  \
# Cluster KMeans
# 0                             0.042573          0.790021      22.091773
# 1                             0.484792         14.294904       7.665831
# 2                             0.071290          2.085575      89.359413
# 3                             0.114846          2.125471       2.903193
#
#                 credit_limit     payments  minimum_payments  prc_full_payment  \
# Cluster KMeans
# 0                4213.207678  1332.194205        639.677258          0.269258
# 1                7546.160857  3484.054216       2003.674460          0.034888
# 2                9696.943765  7288.739497       1972.767288          0.286707
# 3                3279.016289   974.260054        553.900449          0.077981
#
#                    tenure
# Cluster KMeans
# 0               11.594595
# 1               11.386800
# 2               11.951100
# 3               11.446568

# %%
data_transf_kmeans.rename({0:'Pembelanja tertinggi', 1:'Pembelanja sedang', 2:'Pembelanja rendah', 3:'Saldo nol & pembelanja rendah'})
# Out:
#                                    balance  balance_frequency    purchases  \
# Cluster KMeans
# Pembelanja tertinggi            894.907458           0.934734  1236.178934
# Pembelanja sedang              4602.449658           0.968389   501.862982
# Pembelanja rendah              3551.153761           0.986879  7681.620098
# Saldo nol & pembelanja rendah  1012.658327           0.789924   270.041785
#
#                                oneoff_purchases  installments_purchases  \
# Cluster KMeans
# Pembelanja tertinggi                 593.974874              642.478274
# Pembelanja sedang                    320.188797              181.759123
# Pembelanja rendah                   5095.878826             2587.208264
# Saldo nol & pembelanja rendah        209.937299               60.371441
#
#                                cash_advance  purchases_frequency  \
# Cluster KMeans
# Pembelanja tertinggi             210.570626             0.885165
# Pembelanja sedang               4521.509581             0.287832
# Pembelanja rendah                653.638891             0.946418
# Saldo nol & pembelanja rendah    596.509903             0.170145
#
#                                oneoff_purchases_frequency  \
# Cluster KMeans
# Pembelanja tertinggi                             0.297070
# Pembelanja sedang                                0.138911
# Pembelanja rendah                                0.739031
# Saldo nol & pembelanja rendah                    0.086301
#
#                                purchases_installments_frequency  \
# Cluster KMeans
# Pembelanja tertinggi                                   0.711842
# Pembelanja sedang                                      0.185671
# Pembelanja rendah                                      0.788060
# Saldo nol & pembelanja rendah                          0.080558
#
#                                cash_advance_frequency  cash_advance_trx  \
# Cluster KMeans
# Pembelanja tertinggi                         0.042573          0.790021
# Pembelanja sedang                            0.484792         14.294904
# Pembelanja rendah                            0.071290          2.085575
# Saldo nol & pembelanja rendah                0.114846          2.125471
#
#                                purchases_trx  credit_limit     payments  \
# Cluster KMeans
# Pembelanja tertinggi               22.091773   4213.207678  1332.194205
# Pembelanja sedang                   7.665831   7546.160857  3484.054216
# Pembelanja rendah                  89.359413   9696.943765  7288.739497
# Saldo nol & pembelanja rendah       2.903193   3279.016289   974.260054
#
#                                minimum_payments  prc_full_payment     tenure
# Cluster KMeans
# Pembelanja tertinggi                 639.677258          0.269258  11.594595
# Pembelanja sedang                   2003.674460          0.034888  11.386800
# Pembelanja rendah                   1972.767288          0.286707  11.951100
# Saldo nol & pembelanja rendah        553.900449          0.077981  11.446568

# %%
data['Labels'] = data['Cluster KMeans'].map({0:'Pembelanja tertinggi', 1:'Pembelanja sedang', 2:'Pembelanja rendah', 
                                                   3:'Saldo nol & pembelanja rendah'})

data.head()
# Out:
#        balance  balance_frequency  purchases  oneoff_purchases  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    installments_purchases  cash_advance  purchases_frequency  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    oneoff_purchases_frequency  purchases_installments_frequency  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    cash_advance_frequency  cash_advance_trx  purchases_trx  credit_limit  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       payments  minimum_payments  prc_full_payment  tenure  Cluster KMeans  \
# 0   201.802084        139.509787          0.000000      12               3
# 1  4103.032597       1072.340217          0.222222      12               1
# 2   622.066742        627.284787          0.000000      12               0
# 3     0.000000        312.343947          0.000000      12               3
# 4   678.334763        244.791237          0.000000      12               3
#
#                           Labels
# 0  Saldo nol & pembelanja rendah
# 1              Pembelanja sedang
# 2           Pembelanja tertinggi
# 3  Saldo nol & pembelanja rendah
# 4  Saldo nol & pembelanja rendah

# %%
plt.figure(figsize=(14,10))

X = data['balance']
Y = data['purchases']

g = sns.scatterplot(x=X, y=Y, hue=data['Labels'], palette=['blue', 'red', 'green', 'purple'])
g.set_xlabel('Account Balance')
g.set_ylabel('Purchases from Account')
# Out:
# Text(0, 0.5, 'Purchases from Account')

# %% [markdown]
# Plot ini menjelaskan bahwa cluster 0 adalah orang-orang yang banyak berbelanja dengan saldo tertinggi sedangkan cluster 1 adalah orang-orang yang memiliki saldo lebih tinggi tetapi tidak banyak pembelanja. Cluster 2,3 adalah orang yang tidak banyak berbelanja dan memiliki saldo yang relatif lebih rendah (turun ke nol).

# %% [markdown]
# #### Performance Measure tiap Cluster

# %%
# cluster 2
kmeans = KMeans(n_clusters = 2, init = 'k-means++', random_state=0)
kmeans.fit(df_scaler)
pred = kmeans.predict(df_scaler)

## Performance Measure
db_index2 = davies_bouldin_score(df_scaler, pred)
print(db_index2)
# Out:
# 1.912128256522874

# %%
# cluster 3
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state=0)
kmeans.fit(df_scaler)
pred = kmeans.predict(df_scaler)

## Performance Measure
db_index3 = davies_bouldin_score(df_scaler, pred)
print(db_index3)
# Out:
# 1.5971526027526022

# %%
# cluster 4
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state=0)
kmeans.fit(df_scaler)
pred = kmeans.predict(df_scaler)

## Performance Measure
db_index4 = davies_bouldin_score(df_scaler, pred)
print(db_index4)
# Out:
# 1.5748445919846914

# %%
# cluster 5
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state=0)
kmeans.fit(df_scaler)
pred = kmeans.predict(df_scaler)

## Performance Measure
db_index5 = davies_bouldin_score(df_scaler, pred)
print(db_index5)
# Out:
# 1.541660305195426

# %% [markdown]
# ### PCA

# %%
# memproyeksikan data dimensi yang lebih tinggi

from sklearn.decomposition import PCA
pca = PCA()
principalComponents = pca.fit(df_scaler)

# %%
print('Explained variation per principal component:{}'.format(pca.explained_variance_ratio_))
# Out:
# Explained variation per principal component:[2.72973970e-01 2.03137134e-01 8.81330137e-02 7.47940014e-02
#  6.22478774e-02 5.73952684e-02 4.88391462e-02 4.29946812e-02
#  3.79821357e-02 3.08003642e-02 2.37225688e-02 1.77338610e-02
#  1.42791437e-02 1.21691357e-02 1.01266773e-02 2.67033642e-03
#  6.85226801e-07]

# %%
plt.figure(figsize=(12,10))
plt.plot(range(1, 18), pca.explained_variance_ratio_.cumsum(), marker='o', linestyle='--')
plt.title('PCA Captured Variance')
plt.xlabel('Principal Components')
plt.ylabel('Captured Variance')
plt.show()

# %% [markdown]
# Pada tahap ini PCA kembali digunakan dengan tujuan untuk mengurangi data menjadi 2 komponen, agar visualiasi cluster tampak lebih baik.

# %%
pca = PCA(n_components=2, random_state=0)
pca.fit(df_scaler)
pca.components_
# Out:
# array([[ 0.10172563,  0.12048192,  0.41156601,  0.34633694,  0.33676437,
#         -0.02281908,  0.32123637,  0.29449437,  0.27449856, -0.08859005,
#         -0.04814391,  0.39060269,  0.21188664,  0.26647893,  0.06326542,
#          0.13183651,  0.08107505],
#        [ 0.40381966,  0.13133576,  0.04004024,  0.06193195, -0.0191646 ,
#          0.43902716, -0.19114243, -0.01855323, -0.17886356,  0.4341202 ,
#          0.41964292, -0.02015563,  0.23802936,  0.25672452,  0.16906693,
#         -0.19006252, -0.00427084]])

# %%
data_pca = pd.DataFrame(data = pca.components_,
                           columns = dataset.columns.values,
                           index = ['Component 1', 'Component 2'])
data_pca
# Out:
#               balance  balance_frequency  purchases  oneoff_purchases  \
# Component 1  0.101726           0.120482   0.411566          0.346337
# Component 2  0.403820           0.131336   0.040040          0.061932
#
#              installments_purchases  cash_advance  purchases_frequency  \
# Component 1                0.336764     -0.022819             0.321236
# Component 2               -0.019165      0.439027            -0.191142
#
#              oneoff_purchases_frequency  purchases_installments_frequency  \
# Component 1                    0.294494                          0.274499
# Component 2                   -0.018553                         -0.178864
#
#              cash_advance_frequency  cash_advance_trx  purchases_trx  \
# Component 1                -0.08859         -0.048144       0.390603
# Component 2                 0.43412          0.419643      -0.020156
#
#              credit_limit  payments  minimum_payments  prc_full_payment  \
# Component 1      0.211887  0.266479          0.063265          0.131837
# Component 2      0.238029  0.256725          0.169067         -0.190063
#
#                tenure
# Component 1  0.081075
# Component 2 -0.004271

# %%
pca_scores = pca.transform(df_scaler)
pca_scores
# Out:
# array([[-1.68362605, -1.07230075],
#        [-1.13417401,  2.50910255],
#        [ 0.96936728, -0.38358267],
#        ...,
#        [-0.92889822, -1.80801688],
#        [-2.33778069, -0.65360697],
#        [-0.55795527, -0.40058274]])

# %% [markdown]
# #### Features yang paling mempengaruhi komponen

# %%
n_pcs= pca.components_.shape[0]

# %%
most_important = [np.abs(pca.components_[i]).argmax() for i in range(n_pcs)]

# %%
initial_feature_names = ['balance','balance_freq','purchases','oneoff_purchases','install_purchases', 'cash_advance', 'purchases_freq', 'oneoff_purchases_freq',
                        'purchases_install_freq', 'cash_advance_freq', 'cash_advance_trx', 'purchases_trx',
                        'credit_limit', 'payments', 'minim_payments', 'prc_full_pay', 'tenure']

# %%
most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]

# %%
# using LIST COMPREHENSION HERE AGAIN
dic = {'PC{}'.format(i+1): most_important_names[i] for i in range(n_pcs)}

# build the dataframe
df = pd.DataFrame(sorted(dic.items()))
df
# Out:
#      0             1
# 0  PC1     purchases
# 1  PC2  cash_advance

# %% [markdown]
# #### PCA + KMEANS

# %%
wcss = []

for i in range(1, 11):
    kmeans_pca = KMeans(n_clusters= i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans_pca.fit(pca_scores)
    wcss.append(kmeans_pca.inertia_)

plt.plot(range(1,11), wcss, marker='o')
plt.title('K-Means with PCA Components')
plt.xlabel('Number of clusters')
plt.ylabel('wcss')
plt.show()

# %%
kmeans_pca = KMeans(n_clusters = 4, init = 'k-means++', random_state=0)
kmeans_pca.fit(pca_scores)
pred_pca = kmeans_pca.predict(pca_scores)

# %%
data_pca_kmeans = pd.concat([dataset.reset_index(drop=True), pd.DataFrame(pca_scores)], axis=1)
data_pca_kmeans.columns.values[-2:] = ['Component 1', 'Component 2']

data_pca_kmeans['Cluster KMeans+PCA'] = pred_pca
data_pca_kmeans['Cluster KMeans+PCA'].value_counts()
# Out:
# Cluster KMeans+PCA
# 0    3917
# 2    3284
# 3    1245
# 1     504
# Name: count, dtype: int64

# %% [markdown]
# Klaster 0 = Pembelanja tertinggi<br>
# kluster 1 = Pembelanja sedang<br>
# kluster 2 = Pembelanja rendah<br>
# kluster 3 = Saldo nol & pembelanja rendah

# %%
data_pca_kmeans.head()
# Out:
#        balance  balance_frequency  purchases  oneoff_purchases  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    installments_purchases  cash_advance  purchases_frequency  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    oneoff_purchases_frequency  purchases_installments_frequency  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    cash_advance_frequency  cash_advance_trx  purchases_trx  credit_limit  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       payments  minimum_payments  prc_full_payment  tenure  Component 1  \
# 0   201.802084        139.509787          0.000000      12    -1.683626
# 1  4103.032597       1072.340217          0.222222      12    -1.134174
# 2   622.066742        627.284787          0.000000      12     0.969367
# 3     0.000000        312.343947          0.000000      12    -0.888250
# 4   678.334763        244.791237          0.000000      12    -1.600012
#
#    Component 2  Cluster KMeans+PCA
# 0    -1.072301                   0
# 1     2.509103                   3
# 2    -0.383583                   2
# 3     0.004622                   0
# 4    -0.683861                   0

# %%
data_transf_pca = data_pca_kmeans.groupby('Cluster KMeans+PCA').mean()
data_transf_pca
# Out:
#                         balance  balance_frequency    purchases  \
# Cluster KMeans+PCA
# 0                   1014.602733           0.799973   223.007789
# 1                   3404.955669           0.988450  6885.046369
# 2                    822.666371           0.919720  1236.027247
# 3                   4506.117898           0.963486   462.638474
#
#                     oneoff_purchases  installments_purchases  cash_advance  \
# Cluster KMeans+PCA
# 0                         157.542801               65.794187    614.580537
# 1                        4503.028313             2383.208532    771.620430
# 2                         621.813170              614.419160    147.442197
# 3                         300.127390              162.610418   4401.998090
#
#                     purchases_frequency  oneoff_purchases_frequency  \
# Cluster KMeans+PCA
# 0                              0.189871                    0.074899
# 1                              0.954533                    0.725391
# 2                              0.862338                    0.301883
# 3                              0.266593                    0.129829
#
#                     purchases_installments_frequency  cash_advance_frequency  \
# Cluster KMeans+PCA
# 0                                           0.109713                0.122448
# 1                                           0.809325                0.084638
# 2                                           0.675014                0.030698
# 3                                           0.166522                0.471038
#
#                     cash_advance_trx  purchases_trx  credit_limit  \
# Cluster KMeans+PCA
# 0                           2.261680       2.953536   3111.717586
# 1                           2.359127      82.811508   9531.646825
# 2                           0.569732      21.308770   4249.564632
# 3                          13.781526       6.722088   7451.569916
#
#                        payments  minimum_payments  prc_full_payment  \
# Cluster KMeans+PCA
# 0                    855.774716        552.432815          0.065959
# 1                   6712.902567       1881.894509          0.287442
# 2                   1328.724803        574.260980          0.282861
# 3                   3544.363667       2059.187417          0.035020
#
#                        tenure  Component 1  Component 2
# Cluster KMeans+PCA
# 0                   11.364054    -1.364426    -0.194320
# 1                   11.960317     5.993064     0.674360
# 2                   11.661693     0.908460    -1.168986
# 3                   11.439357    -0.529662     3.421864

# %%
data_pca_kmeans['Labels'] = data_pca_kmeans['Cluster KMeans+PCA'].map({0:'Pembelanja tertinggi', 1:'Pembelanja sedang', 2:'Pembelanja rendah', 
                                                                       3:'Saldo nol & pembelanja rendah'})

# %%
plt.figure(figsize=(19,8))

X = data_pca_kmeans['Component 1']
Y = data_pca_kmeans['Component 2']

g = sns.scatterplot(x='Component 1', y='Component 2', hue='Labels', palette=['blue', 'red', 'green', 'purple'], data=data_pca_kmeans)
g.set_title('[Component 1 vs Component 2] Clusters')
plt.show()

# %% [markdown]
# Di sini kita bisa melihat bahwa cluster 0 adalah orang-orang yang banyak berbelanja dengan saldo tertinggi sedangkan cluster 1 adalah orang-orang yang memiliki saldo lebih tinggi tetapi tidak banyak pembelanja. Cluster 2,3 adalah orang yang tidak banyak berbelanja dan memiliki saldo yang relatif lebih rendah (turun ke nol).

# %% [markdown]
# #### Performance Measure tiap Cluster

# %%
# cluster 2
kmeans_pca = KMeans(n_clusters = 2, init = 'k-means++', random_state=0)
kmeans_pca.fit(pca_scores)
pred_pca = kmeans_pca.predict(pca_scores)

## Performance Measure
db_index_pca2 = davies_bouldin_score(pca_scores, pred_pca)
print(db_index_pca2)
# Out:
# 0.9993908152328412

# %%
# cluster 3
kmeans_pca = KMeans(n_clusters = 3, init = 'k-means++', random_state=0)
kmeans_pca.fit(pca_scores)
pred_pca = kmeans_pca.predict(pca_scores)

## Performance Measure
db_index_pca3 = davies_bouldin_score(pca_scores, pred_pca)
print(db_index_pca3)
# Out:
# 0.8118145627277737

# %%
# cluster 4
kmeans_pca = KMeans(n_clusters = 4, init = 'k-means++', random_state=0)
kmeans_pca.fit(pca_scores)
pred_pca = kmeans_pca.predict(pca_scores)

## Performance Measure
db_index_pca4 = davies_bouldin_score(pca_scores, pred_pca)
print(db_index_pca4)
# Out:
# 0.8010250303142444

# %%
# cluster 5
kmeans_pca = KMeans(n_clusters = 5, init = 'k-means++', random_state=0)
kmeans_pca.fit(pca_scores)
pred_pca = kmeans_pca.predict(pca_scores)

## Performance Measure
db_index_pca5 = davies_bouldin_score(pca_scores, pred_pca)
print(db_index_pca5)
# Out:
# 0.7814475567600139

# %% [markdown]
# ### Performance Measure

# %%
# Create Comparison Table 
compare = pd.DataFrame({'Jumlah Cluster': ['2', '3', '4', '5'], 
                        'DBI KMeans': [db_index2, db_index3, db_index4, db_index5],
                       'DBI KMeans+PCA': [db_index_pca2, db_index_pca3, db_index_pca4, db_index_pca5]}).set_index('Jumlah Cluster')
compare
# Out:
#                 DBI KMeans  DBI KMeans+PCA
# Jumlah Cluster
# 2                 1.912128        0.999391
# 3                 1.597153        0.811815
# 4                 1.574845        0.801025
# 5                 1.541660        0.781448

# %%
data_compare = compare.transpose()
data_compare
# Out:
# Jumlah Cluster         2         3         4         5
# DBI KMeans      1.912128  1.597153  1.574845  1.541660
# DBI KMeans+PCA  0.999391  0.811815  0.801025  0.781448

# %% [markdown]
# Model pada clustering K-Means dengan PCA dapat memberikan kualitas hasil cluster yang lebih baik dibandingkan dengan K-Means biasa. hasil evaluasi cluster menunjukkan bahwa model clustering terbaik adalah K-Means dengan reduksi dimensi dataset menjadi 2 dimensi menggunakan PCA dengan nilai DB Index sebesar 0.780573. jumlah cluster yang terbentuk adalah 5

# %% [markdown]
# ### Cluster Terbaik

# %%
kmeans_pca_ = KMeans(n_clusters = 5, init = 'k-means++', random_state=0)
kmeans_pca_.fit(pca_scores)
pred_pca_ = kmeans_pca_.predict(pca_scores)

# %%
data_pca_kmeans_ = pd.concat([dataset.reset_index(drop=True), pd.DataFrame(pca_scores)], axis=1)
data_pca_kmeans_.columns.values[-2:] = ['Component 1', 'Component 2']

data_pca_kmeans_['Cluster KMeans+PCA'] = pred_pca_
data_pca_kmeans_['Cluster KMeans+PCA'].value_counts()
# Out:
# Cluster KMeans+PCA
# 4    3502
# 0    3247
# 2    1082
# 1    1038
# 3      81
# Name: count, dtype: int64

# %% [markdown]
# Klaster 0 = Pembelanja tertinggi<br>
# kluster 1 = Pembelanja sedang<br>
# kluster 2 = Pembelanja hemat<br>
# kluster 3 = Pembelanjaan dengan mencicil<br>
# kluster 4 = Saldo nol & pembelanja dengan mencicil<br>

# %%
data_pca_kmeans_.head()
# Out:
#        balance  balance_frequency  purchases  oneoff_purchases  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    installments_purchases  cash_advance  purchases_frequency  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    oneoff_purchases_frequency  purchases_installments_frequency  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    cash_advance_frequency  cash_advance_trx  purchases_trx  credit_limit  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       payments  minimum_payments  prc_full_payment  tenure  Component 1  \
# 0   201.802084        139.509787          0.000000      12    -1.683626
# 1  4103.032597       1072.340217          0.222222      12    -1.134174
# 2   622.066742        627.284787          0.000000      12     0.969367
# 3     0.000000        312.343947          0.000000      12    -0.888250
# 4   678.334763        244.791237          0.000000      12    -1.600012
#
#    Component 2  Cluster KMeans+PCA
# 0    -1.072301                   4
# 1     2.509103                   2
# 2    -0.383583                   0
# 3     0.004622                   4
# 4    -0.683861                   4

# %%
data_pca_kmeans_['Labels'] = data_pca_kmeans_['Cluster KMeans+PCA'].map({0:'Pembelanja tertinggi', 1:'Pembelanja sedang', 2:'Pembelanja hemat', 
                                                                       3:'Pembelanjaan dengan mencicil', 4:'Saldo nol & pembelanjaan dengan mencicil'})

# %%
plt.figure(figsize=(19,8))

X = data_pca_kmeans_['Component 1']
Y = data_pca_kmeans_['Component 2']

g = sns.scatterplot(x='Component 1', y='Component 2', hue='Labels', palette=['blue', 'red', 'green', 'purple', 'orange'], data=data_pca_kmeans_)
g.set_title('[Component 1 vs Component 2] Clusters')
plt.show()

# %% [markdown]
# Pada scatterplot ini dapat kita lihat bahwa cluster 0 merupakan kalangan orang yang banyak berbelanja dengan saldo tertinggi sedangkan cluster 1 adalah orang-orang yang memiliki saldo lebih tinggi tetapi tidak banyak pembelanja. Adapun cluster 2,3,4 adalah orang yang tidak banyak berbelanja dan memiliki saldo yang relatif lebih rendah (turun ke nol).

# %% [markdown]
# ## Save Model

# %%
import pickle

# %%
pickle.dump(kmeans_pca_, open('KMeans_PCA.pkl', 'wb'))

# %%
pickle.dump(scaler, open('scaler.pkl', 'wb'))

# %%
X_pred = [0, 644]

# %%
pred_pca_ = kmeans_pca_.predict([X_pred])
pred_pca_
# Out:
# array([2])

# %%
PURCHASES = float(input("PURCHASES: "))
CASH_ADVANCE = float(input("CASH_ADVANCE: "))

feature = [
    PURCHASES,
    CASH_ADVANCE,
]

predict = kmeans_pca_.predict([feature])

print("Cluster : ",predict)
# Out:
# PURCHASES: 2
# CASH_ADVANCE: 700
# Cluster :  [2]
